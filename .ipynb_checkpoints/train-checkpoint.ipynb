# %%
# %%time
# %matplotlib inline

import importlib
import new_import  

importlib.reload(new_import)


from new_import import *
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# CPU times: user 80.4 ms, sys: 0 ns, total: 80.4 ms
# Wall time: 108 ms

# %%
# %%time
# Cấu hình Daskgateway
cluster, client = notebook_utils.initialize_dask(use_gateway=True, workers=(1,10))
# Khai báo 1 Datacube là dc
dc = datacube.Datacube()

client
# Out:
# An existing cluster was found. Connecting to: easihub.552e67f82a164db8ad7142f94d6a3bfb
# CPU times: user 34.4 ms, sys: 5.52 ms, total: 39.9 ms
# Wall time: 178 ms
# <Client: 'tls://10.0.62.127:8786' processes=8 threads=64, memory=224.00 GiB>

# %%
# cấu hình thời gian lấy ảnh và tọa độ
date_range = ('2022-09-01', '2023-10-01')
longtitude_range = (105.5, 106.4)
latitude_range = (9.2, 10.0) 

coordinates = (longtitude_range, latitude_range)

# %%
# tải dữ liệu vh vv từ vệ tinh sentinel-1
dsvh, dsvv = load_data_sen1(dc, date_range, coordinates)
# Out:
# <h4>Dataset size: 21.60 GB</h4>
# <xarray.Dataset>
# Dimensions:      (time: 33, y: 8874, x: 9902)
# Coordinates:
#   * time         (time) datetime64[ns] 2022-09-06T22:46:14.500000 ... 2023-09...
#   * y            (y) float64 1.106e+06 1.106e+06 ... 1.017e+06 1.017e+06
#   * x            (x) float64 5.548e+05 5.548e+05 ... 6.538e+05 6.538e+05
#     spatial_ref  int32 32648
# Data variables:
#     vv           (time, y, x) float32 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     vh           (time, y, x) float32 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
# Attributes:
#     crs:           EPSG:32648
#     grid_mapping:  spatial_ref

# %%
average_vv = calculate_average(dsvv, time_pattern='1M')
progress(average_vv)
# Out:
# VBox()

# %%
average_vh = calculate_average(dsvh, time_pattern='1M')
progress(average_vh)
# Out:
# VBox()

# %%
# %%time
average_vh.compute()
average_vv.compute()
# Out:
# CPU times: user 8.09 s, sys: 5.79 s, total: 13.9 s
# Wall time: 32.8 s
# <xarray.DataArray 'vv' (time: 13, y: 8874, x: 9902)>
# array([[[0.06390338, 0.06390338, 0.08360334, ..., 0.23606032,
#          0.23027407, 0.23027407],
#         [0.07378212, 0.07378212, 0.10212713, ..., 0.2547275 ,
#          0.23486657, 0.23486657],
#         [0.07378212, 0.07378212, 0.10212713, ..., 0.2547275 ,
#          0.23486657, 0.23486657],
#         ...,
#         [0.07391845, 0.07391845, 0.07163539, ..., 0.04897952,
#          0.04897952, 0.04933887],
#         [0.07391845, 0.07391845, 0.07163539, ..., 0.04897952,
#          0.04897952, 0.04933887],
#         [0.07355063, 0.07355063, 0.06989169, ..., 0.04626189,
#          0.04626189, 0.04596865]],
#
#        [[0.00889491, 0.00889491, 0.00835034, ..., 0.2334131 ,
#          0.2404511 , 0.2404511 ],
#         [0.00900787, 0.00900787, 0.00830202, ..., 0.28273848,
#          0.27153593, 0.27153593],
#         [0.00900787, 0.00900787, 0.00830202, ..., 0.28273848,
#          0.27153593, 0.27153593],
# ...
#         [0.06728882, 0.06728882, 0.07160655, ..., 0.04366349,
#          0.04366349, 0.04254311],
#         [0.06728882, 0.06728882, 0.07160655, ..., 0.04366349,
#          0.04366349, 0.04254311],
#         [0.08462474, 0.08462474, 0.08174166, ..., 0.04403705,
#          0.04403705, 0.04269896]],
#
#        [[0.10592875, 0.10592875, 0.11522272, ..., 0.2541368 ,
#          0.23525833, 0.23525833],
#         [0.11237547, 0.11237547, 0.12045314, ..., 0.2973504 ,
#          0.26331538, 0.26331538],
#         [0.11237547, 0.11237547, 0.12045314, ..., 0.2973504 ,
#          0.26331538, 0.26331538],
#         ...,
#         [0.11153916, 0.11153916, 0.12090257, ..., 0.05369304,
#          0.05369304, 0.04936117],
#         [0.11153916, 0.11153916, 0.12090257, ..., 0.05369304,
#          0.05369304, 0.04936117],
#         [0.10319728, 0.10319728, 0.09967952, ..., 0.05554755,
#          0.05554755, 0.05302167]]], dtype=float32)
# Coordinates:
#   * y            (y) float64 1.106e+06 1.106e+06 ... 1.017e+06 1.017e+06
#   * x            (x) float64 5.548e+05 5.548e+05 ... 6.538e+05 6.538e+05
#     spatial_ref  int32 32648
#   * time         (time) datetime64[ns] 2022-09-30 2022-10-31 ... 2023-09-30
# Attributes:
#     units:         intensity
#     nodata:        nan
#     crs:           EPSG:32648
#     grid_mapping:  spatial_ref

# %%
data_sen2 = load_data_sen2(dc, date_range, coordinates)
notebook_utils.heading(notebook_utils.xarray_object_size(data_sen2))
display(data_sen2)
# Out:
# Most common native CRS: EPSG:32648
# No datasets require offset correction
# The valid_data_mask and scale (no offset) have been applied to the reflectance bands
# <h4>Dataset size: 111.21 GB</h4>
# <xarray.Dataset>
# Dimensions:      (time: 151, y: 8874, x: 9902)
# Coordinates:
#   * time         (time) datetime64[ns] 2022-09-02T03:35:23.960000 ... 2023-09...
#   * y            (y) float64 1.106e+06 1.106e+06 ... 1.017e+06 1.017e+06
#   * x            (x) float64 5.548e+05 5.548e+05 ... 6.538e+05 6.538e+05
#     spatial_ref  int32 32648
# Data variables:
#     red          (time, y, x) float32 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     nir          (time, y, x) float32 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
#     scl          (time, y, x) uint8 dask.array<chunksize=(1, 2048, 2048), meta=np.ndarray>
# Attributes:
#     crs:           EPSG:32648
#     grid_mapping:  spatial_ref

# %%
# %%time
# Tiến hành loại bỏ các vị trí bị mây ảnh hưởng
result = mask_cloud(data_sen2)
progress(result)
# Out:
# {'0': 'no data',
#  '1': 'saturated or defective',
#  '2': 'dark area pixels',
#  '3': 'cloud shadows',
#  '4': 'vegetation',
#  '5': 'bare soils',
#  '6': 'water',
#  '7': 'unclassified',
#  '8': 'cloud medium probability',
#  '9': 'cloud high probability',
#  '10': 'thin cirrus',
#  '11': 'snow or ice'}
# CPU times: user 1.18 s, sys: 18.2 ms, total: 1.2 s
# Wall time: 1.19 s
# VBox()

# %%
# calculate NDVI
dsNDVI = calculate_indices(result, index='NDVI', satellite_mission='s2')
ndvi = dsNDVI["NDVI"]
display(ndvi)
# Out:
# <xarray.DataArray 'NDVI' (time: 151, y: 8874, x: 9902)>
# dask.array<truediv, shape=(151, 8874, 9902), dtype=float32, chunksize=(1, 2048, 2048), chunktype=numpy.ndarray>
# Coordinates:
#   * time         (time) datetime64[ns] 2022-09-02T03:35:23.960000 ... 2023-09...
#   * y            (y) float64 1.106e+06 1.106e+06 ... 1.017e+06 1.017e+06
#   * x            (x) float64 5.548e+05 5.548e+05 ... 6.538e+05 6.538e+05
#     spatial_ref  int32 32648

# %%
# %%time
# calculate average NDVI
average_ndvi = calculate_average(ndvi,time_pattern="1M")
progress(average_ndvi)
# Out:
# CPU times: user 661 ms, sys: 10.2 ms, total: 671 ms
# Wall time: 669 ms
# VBox()

# %%
# compute average_ndvi
average_ndvi = average_ndvi.compute()

# %%
average_ndvi
# Out:
# <xarray.DataArray 'NDVI' (time: 13, y: 8874, x: 9902)>
# array([[[            nan,             nan,             nan, ...,
#           6.37900054e-01,  6.37840211e-01,  6.00014150e-01],
#         [            nan,             nan,             nan, ...,
#           6.17527306e-01,  6.20078325e-01,  6.24745369e-01],
#         [            nan,             nan,             nan, ...,
#           6.17195070e-01,  6.18910015e-01,  7.56559372e-01],
#         ...,
#         [ 1.72497004e-01,  4.58953112e-01,  2.66808212e-01, ...,
#          -1.07296132e-01, -1.62162170e-01, -1.63636342e-01],
#         [ 1.03626937e-01,  4.47405279e-01,  4.25044090e-01, ...,
#          -1.84331805e-01, -1.42201796e-01, -1.60599545e-01],
#         [-7.29386928e-04,  4.29869354e-01,  4.65222299e-01, ...,
#          -1.11597389e-01, -1.44164741e-01, -1.15226299e-01]],
#
#        [[            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
#         [            nan,             nan,             nan, ...,
#                      nan,             nan,             nan],
# ...
#          -1.16381489e-01, -2.45650217e-01, -2.56057948e-01],
#         [ 1.34953871e-01,  6.61971867e-01,  6.72875404e-01, ...,
#          -1.25083700e-01, -2.16893747e-01, -1.92835450e-01],
#         [ 6.93548396e-02,  5.91334820e-01,  6.62259579e-01, ...,
#          -1.28072619e-01, -1.65681735e-01, -1.16094612e-01]],
#
#        [[            nan,             nan,             nan, ...,
#           8.56177986e-01,  8.37543666e-01,  7.80746520e-01],
#         [            nan,             nan,             nan, ...,
#           8.29926431e-01,  8.19785774e-01,  8.17597389e-01],
#         [            nan,             nan,             nan, ...,
#           8.32685590e-01,  8.06613624e-01,  8.07800591e-01],
#         ...,
#         [ 3.88286322e-01,  6.11940384e-01,  5.17369688e-01, ...,
#          -3.31825316e-02, -2.29459926e-02, -4.85436544e-02],
#         [ 3.34712833e-01,  6.66666687e-01,  6.42252684e-01, ...,
#          -9.60827712e-03,  2.41758358e-02,  2.19135731e-03],
#         [ 2.82383412e-01,  6.62507474e-01,  6.32222235e-01, ...,
#          -2.05527749e-02,  9.85917915e-03, -2.33877134e-02]]],
#       dtype=float32)
# Coordinates:
#   * y            (y) float64 1.106e+06 1.106e+06 ... 1.017e+06 1.017e+06
#   * x            (x) float64 5.548e+05 5.548e+05 ... 6.538e+05 6.538e+05
#     spatial_ref  int32 32648
#   * time         (time) datetime64[ns] 2022-09-30 2022-10-31 ... 2023-09-30

# %%
plt.imshow(average_ndvi.isel(time=6), vmin=None, vmax=None)
average_ndvi.shape
# Out:
# (13, 8874, 9902)

# %%
plt.imshow(dsvh.isel(time=6), vmin=0, vmax=1)

# %%
plt.imshow(dsvv.isel(time=6), vmin=0, vmax=1)

# %%
print(average_ndvi.shape, average_vv.shape, average_vh.shape)
# Out:
# (13, 8874, 9902) (13, 8874, 9902) (13, 8874, 9902)

# %%
mask = ~np.isnan(average_ndvi)

X_train = np.stack([average_vh.values[mask], average_vv.values[mask]], axis=1)
y_train = average_ndvi.values[mask]

# %%
# Kiểm tra có giá trị NaN trong X_train
has_nan = np.isnan(X_train).any()

# In kết quả
if has_nan:
    print("Yes")
else:
    print("No.")
# Out:
# No.

# %%
X_train.shape
# Out:
# (754587870, 2)

# %%
num_samples = 100000

# Generate random indices
random_indices = np.random.choice(X_train.shape[0], size=num_samples, replace=False)

# Subset the data using the random indices
X_train_subset = X_train[random_indices]
y_train_subset = y_train[random_indices]

# Check the new shape
print(X_train_subset.shape)
print(y_train_subset.shape)
# Out:
# (100000, 2)
# (100000,)

# %%
import matplotlib.pyplot as plt

# Lấy dữ liệu VH và VV từ X_train
VH = X_train_subset[:, 0]
VV = X_train_subset[:, 1]

# Vẽ biểu đồ phân tán cho VH và VV
plt.figure(figsize=(8, 6))
scatter = plt.scatter(VH, VV, c=y_train_subset, cmap='viridis', marker='o')
plt.colorbar(scatter, label='NDVI')
plt.xlabel('VH')
plt.ylabel('VV')
plt.title('Scatter plot of VH vs VV colored by NDVI')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# Tạo biểu đồ 3D
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

VH = X_train_subset[:, 0]
VV = X_train_subset[:, 1]
# Vẽ biểu đồ 3D cho VH, VV và NDVI
scatter = ax.scatter(VH, VV, y_train_subset, c=y_train_subset, cmap='viridis', marker='o')
ax.set_xlabel('VH')
ax.set_ylabel('VV')
ax.set_zlabel('NDVI')

# Thêm thanh màu để thấy giá trị NDVI
fig.colorbar(scatter, label='NDVI')
plt.title('3D Scatter plot of VH, VV and NDVI')
plt.show()

# %%
# Chia dữ liệu thành tập huấn luyện và kiểm tra (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_train_subset, y_train_subset, test_size=0.2, random_state=42)

# Kiểm tra kích thước của các tập dữ liệu
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (80000, 2)
# X_test shape: (20000, 2)
# y_train shape: (80000,)
# y_test shape: (20000,)

# %%
# rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
# svr_model = SVR(kernel='poly', degree=2)  # You can change the kernel ('linear', 'poly', 'rbf')
# gb_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
# ln_model = LinearRegression()
# knn_model = KNeighborsRegressor(n_neighbors=5)

# %%
# %%time

# Initialize your model
train_set = (X_train, y_train)
fill_nan_model = find_best_regressor(train_set, "knn")


cross_validate(train_set, fill_nan_model, 5)
# Out:
# Using: KNeighborsRegressor
# Best paras: {'regressor__n_neighbors': 7, 'regressor__weights': 'uniform'}
# Validation scores over splits: [0.040592216, 0.04133944, 0.040128678, 0.041385423, 0.04187737, 0.043897856, 0.0408953, 0.04119592, 0.04136529, 0.040712025]
# Mean validation score: 0.04133895188570023
# CPU times: user 1.64 s, sys: 150 ms, total: 1.79 s
# Wall time: 3.11 s

# %%
folder_path = 'model_train/regressor'
file_path = os.path.join(folder_path, 'fill_nan_model_svr.pkl')
joblib.dump(fill_nan_model, file_path)

# %%
fill_nan_model = joblib.load('model_train/regressor/fill_nan_model_knn.pkl')

# %%
y_pred = fill_nan_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 y_pred = fill_nan_model.predict(X_test)
#       2 mse = mean_squared_error(y_test, y_pred)
#       4 print(f"Mean Squared Error (MSE): {mse}")
#
# File /env/lib/python3.10/site-packages/sklearn/neighbors/_regression.py:237, in KNeighborsRegressor.predict(self, X)
#     221 """Predict the target for the provided data.
#     222
#     223 Parameters
#    (...)
#     232     Target values.
#     233 """
#     234 if self.weights == "uniform":
#     235     # In that case, we do not need the distances to perform
#     236     # the weighting so we do not compute them.
# --> 237     neigh_ind = self.kneighbors(X, return_distance=False)
#     238     neigh_dist = None
#     239 else:
#
# File /env/lib/python3.10/site-packages/sklearn/neighbors/_base.py:804, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     802         X = _check_precomputed(X)
#     803     else:
# --> 804         X = self._validate_data(X, accept_sparse="csr", reset=False, order="C")
#     806 n_samples_fit = self.n_samples_fit_
#     807 if n_neighbors > n_samples_fit:
#
# File /env/lib/python3.10/site-packages/sklearn/base.py:626, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
# --> 626     self._check_n_features(X, reset=reset)
#     628 return out
#
# File /env/lib/python3.10/site-packages/sklearn/base.py:415, in BaseEstimator._check_n_features(self, X, reset)
#     412     return
#     414 if n_features != self.n_features_in_:
# --> 415     raise ValueError(
#     416         f"X has {n_features} features, but {self.__class__.__name__} "
#     417         f"is expecting {self.n_features_in_} features as input."
#     418     )
#
# ValueError: X has 39 features, but KNeighborsRegressor is expecting 2 features as input.

# %%
average_vh
# Out:
# <xarray.DataArray 'vh' (time: 13, y: 8874, x: 9902)>
# dask.array<stack, shape=(13, 8874, 9902), dtype=float32, chunksize=(1, 2048, 2048), chunktype=numpy.ndarray>
# Coordinates:
#   * y            (y) float64 1.106e+06 1.106e+06 ... 1.017e+06 1.017e+06
#   * x            (x) float64 5.548e+05 5.548e+05 ... 6.538e+05 6.538e+05
#     spatial_ref  int32 32648
#   * time         (time) datetime64[ns] 2022-09-30 2022-10-31 ... 2023-09-30
# Attributes:
#     units:         intensity
#     nodata:        nan
#     crs:           EPSG:32648
#     grid_mapping:  spatial_ref

# %%
X_pred = np.stack([average_vh.values[~mask], average_vv.values[~mask]], axis=1)

average_ndvi_filled = xr.DataArray(average_ndvi, dims=average_ndvi.dims)
average_ndvi_filled.values[~mask] = fill_nan_model.predict(X_pred)

# %%
# X_pred = np.stack([average_vh.values[~mask], average_vv.values[~mask]], axis=1)
# average_ndvi.values[~mask] = fill_nan_model.predict(X_pred)
# average_ndvi_filled = xr.DataArray(average_ndvi, dims=average_ndvi.dims)

# %%
plt.imshow(average_ndvi_filled.isel(time=9), vmin=0, vmax=1)

# %%
train_path = "train/ST_training data_updated_1130points.shp"
train = load_data_geo(train_path)

# %%
datasets = create_dataset(train, average_ndvi_filled, average_vh, average_vv)

# %%
len(datasets)
datasets

# %%
# cấu hình nhãn dữ liệu
label_mapping = {
    "Lua tom": "0",
    "Lua": "1",
    "CHN": "2",
    "CLN": "3",
    "TS": "4",
    "Song": "5",
    "Dat xay dung": "6",
    "Rung": "7"
}

# %%
X_tr, X_t, y_tr, y_t = split_train_data(train, label_mapping, datasets)
print(type(X_tr), type(X_t), type(y_tr), type(y_t))
# Out:
# x_new length: 1130, lb_new length: 1130
# X_train length: 904, y_train length: 904
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
data_train=(X_tr, y_t)
model_type='knn'
best_model = find_best_model(dataset=data_train, model_type=model_type)
cross_validate(data_train, best_model, 5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 3
#       1 data_train=(X_tr, y_t)
#       2 model_type='knn'
# ----> 3 best_model = find_best_model(dataset=data_train, model_type=model_type)
#       4 cross_validate(data_train, best_model, 5)
#
# File ~/CODE/new_import.py:361, in find_best_model(dataset, model_type)
#     359 # Use GridSearchCV to find the best parameters
#     360 grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
# --> 361 grid_search.fit(X_train, y_train)
#     362 # Print the classifier name
#     363 print(f"Using classifier: {classifier.__class__.__name__}")
#
# File /env/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File /env/lib/python3.10/site-packages/sklearn/model_selection/_search.py:806, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     803     self._check_refit_for_multimetric(scorers)
#     804     refit_metric = self.refit
# --> 806 X, y, groups = indexable(X, y, groups)
#     807 fit_params = _check_fit_params(X, fit_params)
#     809 cv_orig = check_cv(self.cv, y, classifier=is_classifier(estimator))
#
# File /env/lib/python3.10/site-packages/sklearn/utils/validation.py:453, in indexable(*iterables)
#     434 """Make arrays indexable for cross-validation.
#     435
#     436 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     449     sparse matrix, or dataframe) or `None`.
#     450 """
#     452 result = [_make_indexable(X) for X in iterables]
# --> 453 check_consistent_length(*result)
#     454 return result
#
# File /env/lib/python3.10/site-packages/sklearn/utils/validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [904, 226]

# %%
# kiểm tra độ chính xác với tậ p test
y_pred_test = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(f"Accuracy for test data {round(test_accuracy, 2)*100} %")

# %%
# Lưu mô hình huấn luyện
save_model("best_model.joblib", best_model)

# %%
# đóng client, cluster
client.close()
cluster.close()
